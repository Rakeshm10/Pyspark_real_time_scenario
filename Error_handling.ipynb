# %%
# file which does not exist
try:
    df = spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .load("/Volumes/pyspark/source/rawsource/sales_data_.csv")
    
    df.display()
except Exception as e:
    print(e)

# %%
print(1 + 2 + 5)
